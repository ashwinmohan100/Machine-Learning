# %%
import pandas as pd

# %%
dataset = pd.read_csv("Startups.csv")

# %%
dataset
# Out:
#     R&D Spent  Administration Spent  Marketing Spent    State  Profit
# 0       14500                 12300            12400  Chennai   16400
# 1       13500                 12000            15000  Kolkata   14500
# 2       12300                 12500            14500   Mumbai   15500
# 3       17456                 13546            13546    Dehli   19400
# 4       13456                 13345            12356  Chennai   14550
# 5       15000                 12700            14000  Kolkata   16000
# 6       16000                 13000            15000   Mumbai   17500
# 7       17000                 12900            16000  Chennai   18500
# 8       14000                 12800            13500   Mumbai   15800
# 9       12500                 12200            12000  Kolkata   14200
# 10      15500                 14000            13000    Dehli   17800
# 11      14800                 13800            12800  Chennai   16900
# ...

# %%
print("Column names:", dataset.columns.tolist())
# Out:
# Column names: ['R&D Spent', 'Administration Spent', 'Marketing Spent', 'State', 'Profit']

# %%
dataset_encoded = pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset_encoded
# Out:
#     R&D Spent  Administration Spent  Marketing Spent  Profit  State_Dehli  \
# 0       14500                 12300            12400   16400            0
# 1       13500                 12000            15000   14500            0
# 2       12300                 12500            14500   15500            0
# 3       17456                 13546            13546   19400            1
# 4       13456                 13345            12356   14550            0
# 5       15000                 12700            14000   16000            0
# 6       16000                 13000            15000   17500            0
# 7       17000                 12900            16000   18500            0
# 8       14000                 12800            13500   15800            0
# 9       12500                 12200            12000   14200            0
# 10      15500                 14000            13000   17800            1
# 11      14800                 13800            12800   16900            0
# ...

# %%
dataset_encoded.columns
# Out:
# Index(['R&D Spent', 'Administration Spent', 'Marketing Spent', 'Profit',
#        'State_Dehli', 'State_Kolkata', 'State_Mumbai'],
#       dtype='object')

# %%
independent = dataset_encoded[['R&D Spent', 'Administration Spent', 'Marketing Spent', 'State_Dehli', 'State_Kolkata', 'State_Mumbai']]

# %%
independent
# Out:
#     R&D Spent  Administration Spent  Marketing Spent  State_Dehli  \
# 0       14500                 12300            12400            0
# 1       13500                 12000            15000            0
# 2       12300                 12500            14500            0
# 3       17456                 13546            13546            1
# 4       13456                 13345            12356            0
# 5       15000                 12700            14000            0
# 6       16000                 13000            15000            0
# 7       17000                 12900            16000            0
# 8       14000                 12800            13500            0
# 9       12500                 12200            12000            0
# 10      15500                 14000            13000            1
# 11      14800                 13800            12800            0
# 12      15200                 13400            13200            0
# ...

# %%
dependent = dataset_encoded[['Profit']]

# %%
dependent
# Out:
#     Profit
# 0    16400
# 1    14500
# 2    15500
# 3    19400
# 4    14550
# 5    16000
# 6    17500
# 7    18500
# 8    15800
# 9    14200
# 10   17800
# 11   16900
# 12   17100
# 13   15000
# 14   16300
# 15   18300
# 16   17200
# 17   15900
# 18   17700
# 19   18000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
weight = regressor.coef_
weight
# Out:
# array([[ 8.27373252e-01, -2.12444114e-01,  1.95325436e-02,
#          5.44609746e+02, -6.39560642e+02,  4.52752568e+02]])

# %%
bias=regressor.intercept_
bias
# Out:
# array([6724.84582042])

# %%
y_predict = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_predict)

# %%
r_score
# Out:
# 0.9267169963550408

# %%
import pickle
filename = "finalized_modal_multiple_linear.sav"

# %%
pickle.dump(regressor, open(filename, 'wb'))

# %%
loaded_modal= pickle.load(open(filename, 'rb'))
result=loaded_modal.predict([[14500, 12000, 23000, 0, 0, 0]])
# Out:
# C:\Users\akila\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[16621.67711885]])
